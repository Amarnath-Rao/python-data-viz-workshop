# %%
"""
Python list indexing
NumPy basic syntax
matplotlib introduction
"""
# Out:
# '\nPython list indexing\nNumPy basic syntax\nmatplotlib introduction\n'

# %%
my_list = [1, 2, 3, 4]

# %%
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-e3c7f5a07ede> in <module>()
# ----> 1 my_list[4]
#
# IndexError: list index out of range

# %%
len(my_list)
# Out:
# 4

# %%
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
my_list.append(5)
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
my_list.insert(0, -1)

# %%
print(my_list)
# Out:
# [-1, 1, 2, 3, 4]

# %%
del my_list[2]

# %%
print(my_list)
# Out:
# [-1, 1, 3, 4]

# %%
my_list.remove(4)

# %%
print(my_list)
# Out:
# [-1, 1]

# %%
my_list = [2, 6, 3, 2, 7, 5, 4, 7, 6, 4]

# %%
my_list.sort(reverse=True)

# %%
my_list
# Out:
# [7, 7, 6, 6, 5, 4, 4, 3, 2, 2]

# %%
my_list[2:6]
# Out:
# [6, 6, 5, 4]

# %%
my_list[:5]
# Out:
# [7, 7, 6, 6, 5]

# %%
my_list[5:]
# Out:
# [4, 4, 3, 2, 2]

# %%
my_list[-2]
# Out:
# 2

# %%
my_list[-3:]
# Out:
# [3, 2, 2]

# %%
# Starting Numpy
import numpy as np

np.int8
np.int16
np.int32  # Standard python integer
np.int64

np.float16
np.float64  # Standard python float
np.float256
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-55f438573b76> in <module>()
#       9 np.float16
#      10 np.float64  # Standard python float
# ---> 11 np.float256
#
# AttributeError: module 'numpy' has no attribute 'float256'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10, 40)

# %%
x
# Out:
# array([  0.        ,   0.25641026,   0.51282051,   0.76923077,
#          1.02564103,   1.28205128,   1.53846154,   1.79487179,
#          2.05128205,   2.30769231,   2.56410256,   2.82051282,
#          3.07692308,   3.33333333,   3.58974359,   3.84615385,
#          4.1025641 ,   4.35897436,   4.61538462,   4.87179487,
#          5.12820513,   5.38461538,   5.64102564,   5.8974359 ,
#          6.15384615,   6.41025641,   6.66666667,   6.92307692,
#          7.17948718,   7.43589744,   7.69230769,   7.94871795,
#          8.20512821,   8.46153846,   8.71794872,   8.97435897,
#          9.23076923,   9.48717949,   9.74358974,  10.        ])

# %%
x.shape
# Out:
# (40,)

# %%
sinx = np.sin(x)

# %%
plt.plot(x, sinx)

# %%
x.reshape(4, 10)
# Out:
# array([[  0.        ,   0.25641026,   0.51282051,   0.76923077,
#           1.02564103,   1.28205128,   1.53846154,   1.79487179,
#           2.05128205,   2.30769231],
#        [  2.56410256,   2.82051282,   3.07692308,   3.33333333,
#           3.58974359,   3.84615385,   4.1025641 ,   4.35897436,
#           4.61538462,   4.87179487],
#        [  5.12820513,   5.38461538,   5.64102564,   5.8974359 ,
#           6.15384615,   6.41025641,   6.66666667,   6.92307692,
#           7.17948718,   7.43589744],
#        [  7.69230769,   7.94871795,   8.20512821,   8.46153846,
#           8.71794872,   8.97435897,   9.23076923,   9.48717949,
#           9.74358974,  10.        ]])

# %%
cosx = np.cos(x)

# %%
plt.plot(x, sinx, 'o')
plt.plot(x, cosx, 'x')

# %%
y = sinx * cosx
z = cosx ** 2 - sinx ** 2

# %%
plt.plot(x, y)
plt.plot(x, z)
plt.legend(['sin(x) cos(x)', 'cos(x)^2 - sin(x)^2'])
# http://matplotlib.org/users/legend_guide.html

# %%
np.dot(sinx, cosx)
# Out:
# 0.79265269738691579

# %%
random_list = np.random.random((5, 4))

# %%
random_list
# Out:
# array([[ 0.10160215,  0.19638517,  0.18114557,  0.44743895],
#        [ 0.22978511,  0.28151483,  0.15760194,  0.8515004 ],
#        [ 0.14102359,  0.40204428,  0.33531824,  0.887159  ],
#        [ 0.99371695,  0.63259281,  0.93574292,  0.40019842],
#        [ 0.50737189,  0.69522328,  0.74474918,  0.07566387]])

# %%
random_list[1, 1]
# Out:
# 0.28151482594821708

# %%
a = np.array([[1, 2, 3, 4], [5, 6, 7, 8]], dtype=np.float64)

# %%
a
# Out:
# array([[ 1.,  2.,  3.,  4.],
#        [ 5.,  6.,  7.,  8.]])

# %%
print(a.ndim)
print(a.shape)
print(a.size)
# Out:
# 2
# (2, 4)
# 8

# %%
print(np.random.standard_normal((4, 4)))
# Out:
# [[ 0.58687902  0.15109334  0.59085781  1.65976747]
#  [ 0.33607006 -0.11234594  0.75864456 -0.48617888]
#  [-1.54559726  1.89337696  0.27475704 -2.21918716]
#  [-1.13116517 -0.41494606  0.93628712  0.82470554]]

# %%
a = np.random.standard_normal((2, 3))
b = np.random.standard_normal((2, 3))

# %%
np.vstack([a, b])
# Out:
# array([[-0.11610972,  0.59962024,  2.35640598],
#        [-0.10938713,  0.25340579,  0.22537108],
#        [ 0.2898026 , -0.73885257,  0.6479818 ],
#        [ 1.40726154,  0.13462496, -0.77445899]])

# %%
np.hstack([a, b])
# Out:
# array([[-0.11610972,  0.59962024,  2.35640598,  0.2898026 , -0.73885257,
#          0.6479818 ],
#        [-0.10938713,  0.25340579,  0.22537108,  1.40726154,  0.13462496,
#         -0.77445899]])

# %%
a.T
# Out:
# array([[-0.11610972, -0.10938713],
#        [ 0.59962024,  0.25340579],
#        [ 2.35640598,  0.22537108]])

# %%
a.transpose()
# Out:
# array([[-0.11610972, -0.10938713],
#        [ 0.59962024,  0.25340579],
#        [ 2.35640598,  0.22537108]])

# %%
np.save('array.npy', a)

# %%
loaded_array = np.load('array.npy')

# %%
loaded_array
# Out:
# array([[-0.11610972,  0.59962024,  2.35640598],
#        [-0.10938713,  0.25340579,  0.22537108]])

# %%
a = np.random.random((5, 4))
print(a)
# Out:
# [[ 0.86605881  0.34328046  0.30613523  0.32191526]
#  [ 0.39613612  0.66678478  0.38061782  0.57401435]
#  [ 0.97763981  0.51574922  0.39385415  0.32439499]
#  [ 0.13135189  0.78272864  0.78130271  0.44735846]
#  [ 0.08804111  0.31719408  0.07886734  0.96297163]]

# %%
a[2:4]
# Out:
# array([[ 0.97763981,  0.51574922,  0.39385415,  0.32439499],
#        [ 0.13135189,  0.78272864,  0.78130271,  0.44735846]])

# %%
a[2:4, 2]
# Out:
# array([ 0.39385415,  0.78130271])

# %%
print(a[2, 3])
print(a[2][3])
# Out:
# 0.324394985845
# 0.324394985845

# %%
a[2:4, 1:3]
# Out:
# array([[ 0.51574922,  0.39385415],
#        [ 0.78272864,  0.78130271]])

# %%
a[2:4, :]
# Out:
# array([[ 0.97763981,  0.51574922,  0.39385415,  0.32439499],
#        [ 0.13135189,  0.78272864,  0.78130271,  0.44735846]])

# %%
a[2:4]
# Out:
# array([[ 0.97763981,  0.51574922,  0.39385415,  0.32439499],
#        [ 0.13135189,  0.78272864,  0.78130271,  0.44735846]])

# %%
a[:, ::2]
# step size(2)
# Out:
# array([[ 0.86605881,  0.34328046,  0.30613523,  0.32191526],
#        [ 0.39613612,  0.66678478,  0.38061782,  0.57401435],
#        [ 0.97763981,  0.51574922,  0.39385415,  0.32439499],
#        [ 0.13135189,  0.78272864,  0.78130271,  0.44735846],
#        [ 0.08804111,  0.31719408,  0.07886734,  0.96297163]])

# %%
a > 0.5
# Out:
# array([[ True, False, False, False],
#        [False,  True, False,  True],
#        [ True,  True, False, False],
#        [False,  True,  True, False],
#        [False, False, False,  True]], dtype=bool)

# %%
a[a > 0.5]
# Out:
# array([ 0.86605881,  0.66678478,  0.57401435,  0.97763981,  0.51574922,
#         0.78272864,  0.78130271,  0.96297163])

# %%
import seaborn as sns
sns.set_style('dark')

# %%
plt.plot(np.random.random(100), 'r')

# %%
plt.plot(x, sinx, 'o')
plt.plot(x, cosx, 'g')

# %%
plt.ylim(cosx.min() * 1.5, cosx.max() * 1.5)
plt.xlim(x.min() - 2, x.max() * 1.5)
plt.plot(x, cosx, label='cos(x)')
plt.legend(loc='upper left', frameon=False)

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1),
             xytext=(3, 1.5),
             arrowprops=dict(facecolor='white', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
r = np.arange(0, 1, 0.001)
theta = 2 * 2 * np.pi * r
line, = ax.plot(theta, r,
                color='#ee8d18', lw=7)

ind = 800
thisr, thistheta = r[ind], theta[ind]
ax.plot([thistheta], [thisr], 'o')
ax.annotate('a polar annotation',
            xy=(thistheta, thisr),  # theta, radius
            xytext=(0.05, 0.05),  # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='red', shrink=0.05),
            horizontalalignment='left',
            verticalalignment='bottom',
            )
plt.show()
